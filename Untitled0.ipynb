# %% [markdown]
# <a href="https://colab.research.google.com/github/nataliacb24/Spoon-Knife/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import librosa
import os
import json

from google.colab import drive
drive.mount('/content/gdrive/')
#/content/gdrive/My Drive/
drive = '/content/gdrive/My Drive/'
name_folder = 'tfg_audio/dataset'
DATASET_PATH=drive+name_folder

JSON_PATH = "/content/gdrive/My Drive/tfg_audio/data.json"
SAMPLES_TO_CONSIDER = 22050 # 1 sec. of audio


def preprocess_dataset(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512):
    """Extracts MFCCs from music dataset and saves them into a json file.
    :param dataset_path (str): Path to dataset
    :param json_path (str): Path to json file used to save MFCCs
    :param num_mfcc (int): Number of coefficients to extract
    :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
    :param hop_length (int): Sliding window for FFT. Measured in # of samples
    :return:
    """

    # dictionary where we'll store mapping, labels, MFCCs and filenames
    data = {
        "mapping": [],
        "labels": [],
        "MFCCs": [],
        "files": []
    }

    # loop through all sub-dirs
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're at sub-folder level
        if dirpath is not dataset_path:

            # save label (i.e., sub-folder name) in the mapping
            label = dirpath.split("/")[-1]
            data["mapping"].append(label)
            print("\nProcessing: '{}'".format(label))

            # process all audio files in sub-dir and store MFCCs
            for f in filenames:
                file_path = os.path.join(dirpath, f)

                # load audio file and slice it to ensure length consistency among different files
                signal, sample_rate = librosa.load(file_path)

                # drop audio files with less than pre-decided number of samples
                if len(signal) >= SAMPLES_TO_CONSIDER:

                    # ensure consistency of the length of the signal
                    signal = signal[:SAMPLES_TO_CONSIDER]

                    # extract MFCCs
                    MFCCs = librosa.feature.mfcc(signal, sample_rate, n_mfcc=num_mfcc, n_fft=n_fft,
                                                 hop_length=hop_length)

                    # store data for analysed track
                    data["MFCCs"].append(MFCCs.T.tolist())
                    data["labels"].append(i-1)
                    data["files"].append(file_path)
                    print("{}: {}".format(file_path, i-1))

    # save data in json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)


if __name__ == "__main__":
    preprocess_dataset(DATASET_PATH, JSON_PATH)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/gdrive/My Drive/tfg_audio/dataset/on/cb2929ce_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/bdee441c_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/bfa63751_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5c39594f_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/837f7378_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/0397ecda_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/71f9bba8_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f618568f_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/56f8a100_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5de8f2f0_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/daf230ac_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/df038de4_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3f2b358d_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7c1d8533_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/96a48d28_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b49caed3_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/56f8a100_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d197e3ae_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c6ee87a7_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/36050ef3_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6982fc2a_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/96105282_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ced835d3_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/4c841771_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/54d9ccb5_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3bfd30e6_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/28ed6bc9_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/36050ef3_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/edc53350_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8a5acefd_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cd8b1781_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e14a99a5_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5e3dde6b_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ad63d93c_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ad1429cf_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/439c84f4_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c37a72d3_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cb802c63_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/aa48c94a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7096522d_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5fe4a278_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b0bad4a9_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5c39594f_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/106a6183_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cc6ee39b_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/34e8c726_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c120e80e_nohash_7.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/da1d320c_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/34263ab3_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d1d3e64d_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cb8f8307_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ccea893d_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/fac7deca_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c5e3817f_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/db4cf12f_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/bab36420_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/15c563d7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/747e69fd_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e53139ad_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b9515bf3_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/479e64cc_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c5570933_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/dbb40d24_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ced835d3_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/122c5aa7_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cb2929ce_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/122c5aa7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/dce05676_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/db79a764_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5b09db89_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b49caed3_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c24d96eb_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e7ea8b76_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/0ff728b5_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/953fe1ad_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/15c563d7_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c948d727_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ea356919_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3b7f817e_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f3d06008_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/750e3e75_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cd7f8c1b_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/538e1856_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f3d06008_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3e31dffe_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9db2bfe9_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d0f7bef5_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f3957e23_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cdfbbe75_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b3849d6e_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/27b9a84f_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/24befdb3_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/533c6564_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cb8f8307_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b2e2773a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/716757ce_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a3502f15_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/dff327c5_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b49caed3_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ece1a95a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a4e8a997_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7fd25f7c_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/eb0676ec_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5af0ca83_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e57d35bc_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c7aa72e6_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/876c84d6_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/179a61b7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/380abbad_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/122c5aa7_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9886d8bf_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/692a88e6_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/27b03931_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/0d2bcf9d_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6414258b_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/94de6a6a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c93d5e22_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/28ed6bc9_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/611d2b50_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/41777abb_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/364c0853_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/39a12648_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3bc21161_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3cfc6b3a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f1d36c53_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5b1db3ee_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/fc28c8d8_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/11321027_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/589bce2c_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/37dca74f_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1851e33b_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a97017df_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cb8f8307_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b843de62_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/24befdb3_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a4b21cbc_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b4aa9fef_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b83c1acf_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/bcdaa7a9_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f216055e_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/df038de4_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5b09db89_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a3502f15_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/686d030b_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/77655bdf_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/73cccfaf_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/837f7378_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ab5ae445_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/605ed0ff_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6c2dd2d5_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5ba724a7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/dea820ce_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/079dfce3_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/333784b7_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2bdbe5f7_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/73dda36a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/708a9569_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e53139ad_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/0132a06d_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/617de221_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3852fca2_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6d818f6c_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f6617a86_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/022cd682_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9886d8bf_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7846fd85_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/37dca74f_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d94eb94f_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/079dfce3_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/953fe1ad_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/99a9b015_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b7016c27_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d8d12371_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/39a12648_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f97e1fcd_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d1214f15_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/179a61b7_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d90b4138_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/695c2127_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9cde5de8_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d0faf7e4_nohash_5.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/96ab6565_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3bfd30e6_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/743edf9d_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/0c2d2ffa_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/563aa4e6_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/02e85b60_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7211390b_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/093f65a1_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/adec6a94_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b843de62_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9f869f70_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1b63157b_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9aa21fa9_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f192e6b4_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ad1429cf_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2c6446f7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/45864319_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/0f7205ef_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e57abea3_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5a3712c9_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/105a0eea_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3bdf05d3_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/96ab6565_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b2fbe484_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cd7f8c1b_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/da4ef063_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b83c1acf_nohash_5.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/099d52ad_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/833a0279_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3e31dffe_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8d8d9855_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/58df33b5_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b83c1acf_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5de8f2f0_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e07dd7d4_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/36050ef3_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/333784b7_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/24befdb3_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/dea820ce_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7c1d8533_nohash_5.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cb2929ce_nohash_5.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3ae5c04f_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a7dd45cf_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c93d5e22_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/96a48d28_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7c1d8533_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/66276b0e_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6a1908f8_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/28ed6bc9_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d0f7bef5_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6af4aa07_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/fce65496_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/340c8b10_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/784e281a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/02e85b60_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f174517e_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/64f83f0e_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e7ea8b76_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8056e897_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cd7f8c1b_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/264f471d_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/611d2b50_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d0faf7e4_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/bb31b82b_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/74fc51e5_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5b09db89_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1e412fac_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/179a61b7_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/bab36420_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3ea77ede_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/34e8c726_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9886d8bf_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/611d2b50_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5e3dde6b_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2d3c8dcb_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d3badc9a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/96105282_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2a89ad5c_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b9f46737_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8c888bbb_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/97f4c236_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c948d727_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/07c5129e_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5c39594f_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cc6ee39b_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/df1d5024_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/bdee441c_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5fe4a278_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ec21c46b_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5af0ca83_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f1b35ace_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/db9d52d2_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a827e3a1_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8eb4a1bf_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2ce7534c_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e5e54cee_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/17c94b23_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/815f0f03_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/0fa1e7a9_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a8e25ebb_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7318280c_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e4b02540_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/692a88e6_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/29fb33da_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1cec8d71_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b83c1acf_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/dbb40d24_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3402e488_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c1d39ce8_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/bd061bef_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1626bc5a_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d0faf7e4_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/bf5d409d_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/4abb2400_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/24c9f572_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/bbbf4fbd_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/42ccb57a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5de8f2f0_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/409c962a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9a7c1f83_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/16db1582_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/19e98e89_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cae62f38_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6166ae21_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f8f60f59_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5a3712c9_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c79159aa_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/03c96658_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b11a05d2_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e0315cf6_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/dbb40d24_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c9b653a0_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d7467392_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/73f0c1f7_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8281a2a8_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e805a617_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cc6ee39b_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e3b64217_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b3bdded5_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8f0d3c27_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/37dca74f_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d069e6ff_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/617de221_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/4a1e736b_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/51f4d5b0_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8eb4a1bf_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9a7c1f83_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e5c48e53_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ad340ed7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5fadb538_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/89e59d18_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9ab86dd0_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f8f60f59_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e5c48e53_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a1c63f25_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a2fefcb4_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/01bcfc0c_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b83c1acf_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/39a12648_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e9a76b2f_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ad9de4dd_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f3d06008_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5e3dde6b_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/735845ab_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d7529c0c_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/76e53db9_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/229978fd_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/837f7378_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f8f60f59_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2a0b413e_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b8872c20_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/179a61b7_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/67961766_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b8872c20_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/34e8c726_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/99a9b015_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/39a6b995_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ac7840d8_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/551e42e8_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c79159aa_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e7ea8b76_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/15c563d7_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/96cd0255_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8c4854bc_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7c1d8533_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d6b155a5_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ba676390_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b5aacf2c_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8bf6acb9_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2a89ad5c_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/57cb3575_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/adc216c5_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/19e246ad_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/782c1305_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b11a05d2_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3ae5c04f_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/24632875_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ec74a8a5_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c842b5e4_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a3255f5c_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8281a2a8_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1b459024_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5e3dde6b_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b5aacf2c_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b9515bf3_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/05b2db80_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d197e3ae_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/716757ce_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1a673010_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3d9200b9_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/fb7c9b3b_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/106a6183_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c9b653a0_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/eb0676ec_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/765ffccb_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c634a189_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/4d9e07cf_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2b1dffa7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e2362167_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e9a76b2f_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/31e686d2_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c93d5e22_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/86f12ac0_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/988e2f9a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/747e69fd_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/686d030b_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c7aa72e6_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e20be42a_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/df1d5024_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/12c206ea_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b4aa9fef_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7c9b43f0_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/712e4d58_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b9f46737_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/840c366d_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1bb574f9_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d0faf7e4_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c6ca5d01_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/692a88e6_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/611d2b50_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/0137b3f4_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/712e4d58_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7318280c_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5be23def_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/834f03fe_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/57cb3575_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7e843da8_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/692a88e6_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c1e0e8e3_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c6ee87a7_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6982fc2a_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/364c0853_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/da584bc0_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/4290ca61_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/88e90bc1_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3cdecb0b_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/324210dd_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d1d3e64d_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/823353e5_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c1d39ce8_nohash_5.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5f1b1051_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b544d4fd_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a50a98d2_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e2008f39_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b9db6e42_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/96a48d28_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/340c8b10_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/130d9a87_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e96a5020_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3f2b358d_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b9f46737_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1b835b87_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ccf418a5_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6c0f6493_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d33df435_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1cbcc7a7_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/229978fd_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d90b4138_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3bc21161_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8f0d3c27_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/eb76bc68_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d8c52371_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6e916de8_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/130d9a87_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6c2dd2d5_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2039b9c1_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b9515bf3_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d55aa56c_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/96ab6565_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c0c0d87d_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d1d3e64d_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/fbf3dd31_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f632210f_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c1d39ce8_nohash_6.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6846af18_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/97ae8b25_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f57469fb_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/772db621_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/951cac20_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/951cac20_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/712e4d58_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/fb24c826_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5fb88f4c_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/122c5aa7_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3c257192_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/620ff0fa_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/569455ff_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/bab36420_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/56eab10e_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/97101ef3_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/0137b3f4_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8c888bbb_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/69f609ec_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/91bed2e0_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d5c41d6a_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/df1d5024_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/00b01445_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c948d727_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d8ed3745_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/32efce64_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f15a354c_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7211390b_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/834f03fe_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/45864319_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/14872d06_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/88e90bc1_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a8e25ebb_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1d1fe0a0_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b665723d_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8830e17f_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/742d6431_nohash_5.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b41a92a3_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9a7c1f83_nohash_5.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/becd5a53_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6a27a9bf_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b8897f1c_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/30802c5d_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/97f4c236_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/54412eae_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7106d229_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6982fc2a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9aa21fa9_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/28ed6bc9_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9a69672b_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6846af18_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/099d52ad_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cb2929ce_nohash_6.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/afe0b87d_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d90b4138_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e855b8f1_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c120e80e_nohash_5.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2bdbe5f7_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/324210dd_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5fadb538_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2643992f_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a827e3a1_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/dc7ec25b_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3bfd30e6_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/72d75d96_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/72be9202_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cb802c63_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/4b25f620_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1c1060b1_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/81a345a3_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2bdbe5f7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/190821dc_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f8f60f59_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/29fb33da_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3d3ddaf8_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/dbb40d24_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/94de6a6a_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/75915c90_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e53139ad_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8281a2a8_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7fd25f7c_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1093c8e7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c0e0f834_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/da584bc0_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d8c52371_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ced835d3_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/50a8ef27_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9a7c1f83_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b59fe16d_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7211390b_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/439c84f4_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1995cf9e_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e62056e2_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d7529c0c_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e96a5020_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/96c67073_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3ed3e49a_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8442ea62_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/106a6183_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cb2929ce_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2b3f509b_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/333784b7_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7257420c_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/4c841771_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6e916de8_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/686d030b_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ec74a8a5_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5fadb538_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/099d52ad_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/37dca74f_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/28e47b1a_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/9a7c1f83_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c24d96eb_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7f74626f_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c842b5e4_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/617de221_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7211390b_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ed3c2d05_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b11a05d2_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/190821dc_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/659b7fae_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6f9088d7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/0137b3f4_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5ff3f9a1_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/8910e5ef_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/a1cff772_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/0c2ca723_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/563aa4e6_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/56f8a100_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/36de13e1_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3a33d3a4_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/82e7204d_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e57abea3_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/73f0c1f7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c0f8f4df_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/4def68db_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/dea820ce_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/36050ef3_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/df1d5024_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1daa5ada_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b3849d6e_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/47d01978_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/afe0b87d_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/24632875_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1942abd7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/db4cf12f_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3dfd6c23_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b83c1acf_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/179a61b7_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7fd25f7c_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/e5dadd24_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/fac7deca_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/409c962a_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/db9d52d2_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d9b8fab2_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/88120683_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/686d030b_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/f810e799_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/5f1b1051_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7fd25f7c_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/24694eb6_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/34881b10_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d5c41d6a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b9f46737_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/65c73b55_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/953fe1ad_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/cae62f38_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/324210dd_nohash_4.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3e31dffe_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d8ed3745_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6c2dd2d5_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/12c206ea_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/6dfff95a_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/73cccfaf_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/bdee441c_nohash_2.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/ac899eb7_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/7846fd85_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/de6eb27c_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/dce05676_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/84d1e469_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/4a4e28f1_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/42beb5eb_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/b4aa9fef_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/264f471d_nohash_3.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/facd97c0_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/1b459024_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/2a89ad5c_nohash_1.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/d6b155a5_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/c0445658_nohash_0.wav: 7
# /content/gdrive/My Drive/tfg_audio/dataset/on/3c257192_nohash_0.wav: 7
#
# Processing: 'stop'
# /content/gdrive/My Drive/tfg_audio/dataset/stop/ffa76c4a_nohash_1.wav: 8
# /content/gdrive/My Drive/tfg_audio/dataset/stop/eb3f7d82_nohash_1.wav: 8
# /content/gdrive/My Drive/tfg_audio/dataset/stop/e9901cf0_nohash_0.wav: 8
# /content/gdrive/My Drive/tfg_audio/dataset/stop/471a0925_nohash_2.wav: 8
# /content/gdrive/My Drive/tfg_audio/dataset/stop/f4386675_nohash_0.wav: 8
# /content/gdrive/My Drive/tfg_audio/dataset/stop/653a48f5_nohash_0.wav: 8
# /content/gdrive/My Drive/tfg_audio/dataset/stop/3c257192_nohash_2.wav: 8
# /content/gdrive/My Drive/tfg_audio/dataset/stop/3bfd30e6_nohash_2.wav: 8
# /content/gdrive/My Drive/tfg_audio/dataset/stop/3da7f617_nohash_0.wav: 8
# ...
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8d9cc260_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/0685264e_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/9bea2ac7_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/eb0676ec_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/b84f83d2_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/023a61ad_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/ec74a8a5_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/d85270c1_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/0f3f64d5_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/da584bc0_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/e5afa9b0_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/db79a764_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/190821dc_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/353b4d33_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/6f2f57c1_nohash_3.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/7d149b38_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/cb8f8307_nohash_5.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/439c84f4_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/9aa5439d_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/e0a7c5a0_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/82305c3a_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/cf8d91cf_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/3e3fa7fd_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/611d2b50_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/11321027_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/0132a06d_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/1a5b9ca4_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/7096522d_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/bfb10243_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8f4c551f_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8b39e36f_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/617de221_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/da2c5f1b_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/5d0ab165_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/7d5f87c8_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/07c5129e_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/4abefdf5_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/71904de3_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/c25a032b_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/15c563d7_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/1a673010_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/39a12648_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/48a8a69d_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/735845ab_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/6205088b_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8a5acefd_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/4ec7d027_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/1ed557b9_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/24befdb3_nohash_3.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/2b3f509b_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/82b99576_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/ccb1266b_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/a879a2c3_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/953fe1ad_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/da2c5f1b_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/409c962a_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/df6bd83f_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/b83c1acf_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/1b459024_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/0137b3f4_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/18a8f03f_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/750e3e75_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/d952a17e_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/c4cfbe43_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/b9db6e42_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/32561e9e_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/39a12648_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8d9cc260_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/24befdb3_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/38d78313_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/0137b3f4_nohash_3.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/026290a7_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/5fe4a278_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/e95c70e2_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/59c3a7f2_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/ffbb695d_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/dea820ce_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/eb0857c0_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/1b88bf70_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/4e8c5516_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/34805883_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/264f471d_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/96ab6565_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/fac74f6a_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/bab36420_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8830e17f_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/0474c92a_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/da1d320c_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/bab36420_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/e48a80ed_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/36de13e1_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/b9db6e42_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/928cc2ef_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/e5e54cee_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/86f12ac0_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/51995cea_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/d3a18257_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/c6ee87a7_nohash_3.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/439c84f4_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/eefd26f3_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/bab36420_nohash_3.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/24632875_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/7f74626f_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/dbb40d24_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/e7ea8b76_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8281a2a8_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/563aa4e6_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/0132a06d_nohash_3.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/94de6a6a_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/29fb33da_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/66cbe2b3_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/d312f481_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/370844f7_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/1b88bf70_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/bfaf2000_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/24c9f572_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/28460a60_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/bfa63751_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/0137b3f4_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/cb8f8307_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/66a412a7_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/6a27a9bf_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/72d75d96_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8a28231e_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/6a27a9bf_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/f6af2457_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/4249c833_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/ac899eb7_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/c8771f88_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/11099149_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/1cb788bc_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/caa7feaf_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/39ec87ac_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/1c1060b1_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8eb4a1bf_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/28ed6bc9_nohash_3.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/57376a4c_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8281a2a8_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/71f6fed7_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/cd7f8c1b_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/e652590d_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/96ab6565_nohash_3.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/da1d320c_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8a5acefd_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/39a12648_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/311fde72_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/1cc80e39_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/6c968bd9_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/493392c6_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/6846af18_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/97f4c236_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/56cd307a_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/190821dc_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/50d1c8e3_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/e53139ad_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/92e17cc4_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/fce65496_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/270bfa52_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/6a497f80_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/5d9bb361_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/3bc21161_nohash_3.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8c7f81df_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/333784b7_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/f638a812_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/439c84f4_nohash_3.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/bf4af1af_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/742d6431_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/30a09789_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/d7ca14ef_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8d9cc260_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/e7ea8b76_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/24694eb6_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/4a1e736b_nohash_3.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/c93d5e22_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/d8ed3745_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/adc216c5_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/97f4c236_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/28ed6bc9_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/617de221_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/190821dc_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/b83c1acf_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/023a61ad_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/370844f7_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/aac5b7c1_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/f5733968_nohash_4.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/1a9afd33_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/171b56dc_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/3c8dc702_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/06a79a03_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/617de221_nohash_3.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/53458368_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/dabf67d9_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8281a2a8_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/1df483c0_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/c25a032b_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/6c968bd9_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/97addd88_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/439c84f4_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/3d3ddaf8_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/0c2d2ffa_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/e7d0eb3f_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/11b1df78_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/96ab6565_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/4f2be90f_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/fac74f6a_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/78030270_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/5b09db89_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/5188de0d_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/9aa21fa9_nohash_2.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/190821dc_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/2bdbe5f7_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/264f471d_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/8781f4c1_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/82305c3a_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/c93d5e22_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/ff21fb59_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/745a8e32_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/de08912f_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/df280250_nohash_0.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/97addd88_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/4f256313_nohash_1.wav: 9
# /content/gdrive/My Drive/tfg_audio/dataset/yes/a4b21cbc_nohash_0.wav: 9

# %%
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from google.colab import drive
drive.mount('/content/gdrive/')
#/content/gdrive/My Drive/
drive = '/content/gdrive/My Drive/'
name_folder_json = "tfg_audio/data.json"
DATA_PATH=drive+name_folder_json

#DATA_PATH = "data.json"
SAVED_MODEL_PATH = "/content/gdrive/My Drive/tfg_audio/model.h5"
EPOCHS = 40
BATCH_SIZE = 32
PATIENCE = 5
LEARNING_RATE = 0.0001


def load_data(data_path):
    """Loads training dataset from json file.
    :param data_path (str): Path to json file containing data
    :return X (ndarray): Inputs
    :return y (ndarray): Targets
    """
    print(data_path)
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["MFCCs"])
    y = np.array(data["labels"])
    print("Training sets loaded!")
    return X, y


def prepare_dataset(data_path, test_size=0.2, validation_size=0.2):
    """Creates train, validation and test sets.
    :param data_path (str): Path to json file containing data
    :param test_size (flaot): Percentage of dataset used for testing
    :param validation_size (float): Percentage of train set used for cross-validation
    :return X_train (ndarray): Inputs for the train set
    :return y_train (ndarray): Targets for the train set
    :return X_validation (ndarray): Inputs for the validation set
    :return y_validation (ndarray): Targets for the validation set
    :return X_test (ndarray): Inputs for the test set
    :return X_test (ndarray): Targets for the test set
    """

    # load dataset
    X, y = load_data(data_path)

    # create train, validation, test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to nd array
    X_train = X_train[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]

    return X_train, y_train, X_validation, y_validation, X_test, y_test


def build_model(input_shape, loss="sparse_categorical_crossentropy", learning_rate=0.0001):
    """Build neural network using keras.
    :param input_shape (tuple): Shape of array representing a sample train. E.g.: (44, 13, 1)
    :param loss (str): Loss function to use
    :param learning_rate (float):
    :return model: TensorFlow model
    """

    # build network architecture using convolutional layers
    model = tf.keras.models.Sequential()

    # 1st conv layer
    model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape,
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding='same'))

    # 2nd conv layer
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu',
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding='same'))

    # 3rd conv layer
    model.add(tf.keras.layers.Conv2D(32, (2, 2), activation='relu',
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((2, 2), strides=(2,2), padding='same'))

    # flatten output and feed into dense layer
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    tf.keras.layers.Dropout(0.3)

    # softmax output layer
    model.add(tf.keras.layers.Dense(10, activation='softmax'))

    optimiser = tf.optimizers.Adam(learning_rate=learning_rate)

    # compile model
    model.compile(optimizer=optimiser,
                  loss=loss,
                  metrics=["accuracy"])

    # print model parameters on console
    model.summary()

    return model


def train(model, epochs, batch_size, patience, X_train, y_train, X_validation, y_validation):
    """Trains model
    :param epochs (int): Num training epochs
    :param batch_size (int): Samples per batch
    :param patience (int): Num epochs to wait before early stop, if there isn't an improvement on accuracy
    :param X_train (ndarray): Inputs for the train set
    :param y_train (ndarray): Targets for the train set
    :param X_validation (ndarray): Inputs for the validation set
    :param y_validation (ndarray): Targets for the validation set
    :return history: Training history
    """

    earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor="accuracy", min_delta=0.001, patience=patience)

    # train model
    history = model.fit(X_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(X_validation, y_validation),
                        callbacks=[earlystop_callback])
    return history


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
    :param history: Training history of model
    :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy subplot
    axs[0].plot(history.history["accuracy"], label="accuracy")
    axs[0].plot(history.history['val_accuracy'], label="val_accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy evaluation")

    # create loss subplot
    axs[1].plot(history.history["loss"], label="loss")
    axs[1].plot(history.history['val_loss'], label="val_loss")
    axs[1].set_xlabel("Epoch")
    axs[1].set_ylabel("Loss")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Loss evaluation")

    plt.show()


def main():
    # generate train, validation and test sets
    X_train, y_train, X_validation, y_validation, X_test, y_test = prepare_dataset(DATA_PATH)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape, learning_rate=LEARNING_RATE)

    # train network
    history = train(model, EPOCHS, BATCH_SIZE, PATIENCE, X_train, y_train, X_validation, y_validation)

    # plot accuracy/loss for training/validation set as a function of the epochs
    plot_history(history)

    # evaluate network on test set
    test_loss, test_acc = model.evaluate(X_test, y_test)
    print("\nTest loss: {}, test accuracy: {}".format(test_loss, 100*test_acc))

    # save model
    model.save(SAVED_MODEL_PATH)


if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/My Drive/tfg_audio/data.json
# Training sets loaded!
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 42, 11, 64)        640
#
#  batch_normalization (BatchN  (None, 42, 11, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 21, 6, 64)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 19, 4, 32)         18464
#
#  batch_normalization_1 (Batc  (None, 19, 4, 32)        128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 2, 32)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 9, 1, 32)          4128
#
#  batch_normalization_2 (Batc  (None, 9, 1, 32)         128
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 1, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 160)               0
#
#  dense (Dense)               (None, 64)                10304
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 34,698
# Trainable params: 34,442
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/40
# 393/393 [==============================] - 29s 71ms/step - loss: 2.0433 - accuracy: 0.3417 - val_loss: 1.6130 - val_accuracy: 0.4801
# Epoch 2/40
# 393/393 [==============================] - 21s 54ms/step - loss: 1.3458 - accuracy: 0.5934 - val_loss: 1.1974 - val_accuracy: 0.6455
# Epoch 3/40
# 393/393 [==============================] - 22s 56ms/step - loss: 1.0030 - accuracy: 0.7155 - val_loss: 0.9590 - val_accuracy: 0.7195
# Epoch 4/40
# 393/393 [==============================] - 25s 63ms/step - loss: 0.7967 - accuracy: 0.7819 - val_loss: 0.7786 - val_accuracy: 0.7874
# Epoch 5/40
# 393/393 [==============================] - 22s 57ms/step - loss: 0.6673 - accuracy: 0.8210 - val_loss: 0.6788 - val_accuracy: 0.8055
# Epoch 6/40
# 393/393 [==============================] - 21s 54ms/step - loss: 0.5869 - accuracy: 0.8432 - val_loss: 0.6154 - val_accuracy: 0.8307
# Epoch 7/40
# 393/393 [==============================] - 23s 58ms/step - loss: 0.5227 - accuracy: 0.8638 - val_loss: 0.5676 - val_accuracy: 0.8438
# Epoch 8/40
# 393/393 [==============================] - 22s 56ms/step - loss: 0.4703 - accuracy: 0.8769 - val_loss: 0.5279 - val_accuracy: 0.8553
# Epoch 9/40
# 393/393 [==============================] - 22s 56ms/step - loss: 0.4436 - accuracy: 0.8829 - val_loss: 0.5102 - val_accuracy: 0.8610
# Epoch 10/40
# 393/393 [==============================] - 22s 57ms/step - loss: 0.4025 - accuracy: 0.8959 - val_loss: 0.4935 - val_accuracy: 0.8668
# Epoch 11/40
# 393/393 [==============================] - 21s 54ms/step - loss: 0.3840 - accuracy: 0.9027 - val_loss: 0.4614 - val_accuracy: 0.8738
# Epoch 12/40
# 393/393 [==============================] - 23s 58ms/step - loss: 0.3573 - accuracy: 0.9112 - val_loss: 0.4532 - val_accuracy: 0.8760
# Epoch 13/40
# 393/393 [==============================] - 21s 55ms/step - loss: 0.3448 - accuracy: 0.9138 - val_loss: 0.4811 - val_accuracy: 0.8588
# Epoch 14/40
# 393/393 [==============================] - 21s 54ms/step - loss: 0.3335 - accuracy: 0.9185 - val_loss: 0.4193 - val_accuracy: 0.8821
# Epoch 15/40
# 393/393 [==============================] - 24s 60ms/step - loss: 0.3109 - accuracy: 0.9240 - val_loss: 0.4274 - val_accuracy: 0.8824
# Epoch 16/40
# 393/393 [==============================] - 21s 54ms/step - loss: 0.2944 - accuracy: 0.9306 - val_loss: 0.4177 - val_accuracy: 0.8824
# Epoch 17/40
# 393/393 [==============================] - 21s 54ms/step - loss: 0.2919 - accuracy: 0.9315 - val_loss: 0.4602 - val_accuracy: 0.8712
# Epoch 18/40
# 393/393 [==============================] - 23s 58ms/step - loss: 0.2856 - accuracy: 0.9328 - val_loss: 0.3993 - val_accuracy: 0.8945
# Epoch 19/40
# 393/393 [==============================] - 22s 55ms/step - loss: 0.2666 - accuracy: 0.9370 - val_loss: 0.3984 - val_accuracy: 0.8875
# Epoch 20/40
# 393/393 [==============================] - 22s 55ms/step - loss: 0.2595 - accuracy: 0.9393 - val_loss: 0.3777 - val_accuracy: 0.8983
# Epoch 21/40
# 393/393 [==============================] - 20s 52ms/step - loss: 0.2496 - accuracy: 0.9413 - val_loss: 0.3739 - val_accuracy: 0.8974
# Epoch 22/40
# 393/393 [==============================] - 22s 56ms/step - loss: 0.2428 - accuracy: 0.9453 - val_loss: 0.3770 - val_accuracy: 0.8989
# Epoch 23/40
# 393/393 [==============================] - 23s 59ms/step - loss: 0.2357 - accuracy: 0.9465 - val_loss: 0.3616 - val_accuracy: 0.9060
# Epoch 24/40
# 393/393 [==============================] - 23s 59ms/step - loss: 0.2350 - accuracy: 0.9482 - val_loss: 0.3760 - val_accuracy: 0.8954
# Epoch 25/40
# 393/393 [==============================] - 24s 60ms/step - loss: 0.2220 - accuracy: 0.9519 - val_loss: 0.3620 - val_accuracy: 0.9015
# Epoch 26/40
# 393/393 [==============================] - 26s 66ms/step - loss: 0.2134 - accuracy: 0.9546 - val_loss: 0.3587 - val_accuracy: 0.9060
# Epoch 27/40
# 393/393 [==============================] - 25s 63ms/step - loss: 0.2091 - accuracy: 0.9546 - val_loss: 0.3688 - val_accuracy: 0.9009
# Epoch 28/40
# 393/393 [==============================] - 24s 61ms/step - loss: 0.2008 - accuracy: 0.9559 - val_loss: 0.4036 - val_accuracy: 0.8884
# Epoch 29/40
# 393/393 [==============================] - 24s 61ms/step - loss: 0.2093 - accuracy: 0.9537 - val_loss: 0.3681 - val_accuracy: 0.8977
# Epoch 30/40
# 393/393 [==============================] - 25s 63ms/step - loss: 0.1911 - accuracy: 0.9613 - val_loss: 0.3599 - val_accuracy: 0.9056
# Epoch 31/40
# 393/393 [==============================] - 27s 69ms/step - loss: 0.1931 - accuracy: 0.9598 - val_loss: 0.3487 - val_accuracy: 0.9104
# Epoch 32/40
# 393/393 [==============================] - 24s 61ms/step - loss: 0.1854 - accuracy: 0.9611 - val_loss: 0.3614 - val_accuracy: 0.9082
# Epoch 33/40
# 393/393 [==============================] - 22s 57ms/step - loss: 0.1925 - accuracy: 0.9588 - val_loss: 0.3492 - val_accuracy: 0.9060
# Epoch 34/40
# 393/393 [==============================] - 22s 57ms/step - loss: 0.1794 - accuracy: 0.9628 - val_loss: 0.3533 - val_accuracy: 0.9107
# Epoch 35/40
# 393/393 [==============================] - 23s 59ms/step - loss: 0.1739 - accuracy: 0.9649 - val_loss: 0.3603 - val_accuracy: 0.9072
# Epoch 36/40
# 393/393 [==============================] - 23s 59ms/step - loss: 0.1699 - accuracy: 0.9678 - val_loss: 0.3688 - val_accuracy: 0.9012
# Epoch 37/40
# 393/393 [==============================] - 22s 56ms/step - loss: 0.1660 - accuracy: 0.9667 - val_loss: 0.3570 - val_accuracy: 0.9066
# Epoch 38/40
# 393/393 [==============================] - 22s 57ms/step - loss: 0.1726 - accuracy: 0.9646 - val_loss: 0.3498 - val_accuracy: 0.9076
# Epoch 39/40
# 393/393 [==============================] - 22s 56ms/step - loss: 0.1624 - accuracy: 0.9683 - val_loss: 0.3645 - val_accuracy: 0.9037
# Epoch 40/40
# 393/393 [==============================] - 21s 54ms/step - loss: 0.1566 - accuracy: 0.9700 - val_loss: 0.3536 - val_accuracy: 0.9066
# 123/123 [==============================] - 1s 12ms/step - loss: 0.2897 - accuracy: 0.9276
#
# Test loss: 0.2896508574485779, test accuracy: 92.75879859924316

# %%
import librosa
import tensorflow as tf
import numpy as np

SAVED_MODEL_PATH = "/content/gdrive/My Drive/tfg_audio/model.h5"
SAMPLES_TO_CONSIDER = 22050


class _Keyword_Spotting_Service:
    """Singleton class for keyword spotting inference with trained models.
    :param model: Trained model
    """

    model = None
    _mapping = [
        "down",
        "off",
        "on",
        "no",
        "yes",
        "stop",
        "up",
        "right",
        "left",
        "go"
    ]
    _instance = None


    def predict(self, file_path):
        """
        :param file_path (str): Path to audio file to predict
        :return predicted_keyword (str): Keyword predicted by the model
        """

        # extract MFCC
        MFCCs = self.preprocess(file_path)

        # we need a 4-dim array to feed to the model for prediction: (# samples, # time steps, # coefficients, 1)
        MFCCs = MFCCs[np.newaxis, ..., np.newaxis]

        # get the predicted label
        predictions = self.model.predict(MFCCs)
        predicted_index = np.argmax(predictions)
        predicted_keyword = self._mapping[predicted_index]
        return predicted_keyword


    def preprocess(self, file_path, num_mfcc=13, n_fft=2048, hop_length=512):
        """Extract MFCCs from audio file.
        :param file_path (str): Path of audio file
        :param num_mfcc (int): # of coefficients to extract
        :param n_fft (int): Interval we consider to apply STFT. Measured in # of samples
        :param hop_length (int): Sliding window for STFT. Measured in # of samples
        :return MFCCs (ndarray): 2-dim array with MFCC data of shape (# time steps, # coefficients)
        """

        # load audio file
        signal, sample_rate = librosa.load(file_path)

        if len(signal) >= SAMPLES_TO_CONSIDER:
            # ensure consistency of the length of the signal
            signal = signal[:SAMPLES_TO_CONSIDER]

            # extract MFCCs
            MFCCs = librosa.feature.mfcc(signal, sample_rate, n_mfcc=num_mfcc, n_fft=n_fft,
                                         hop_length=hop_length)
        return MFCCs.T


def Keyword_Spotting_Service():
    """Factory function for Keyword_Spotting_Service class.
    :return _Keyword_Spotting_Service._instance (_Keyword_Spotting_Service):
    """

    # ensure an instance is created only the first time the factory function is called
    if _Keyword_Spotting_Service._instance is None:
        _Keyword_Spotting_Service._instance = _Keyword_Spotting_Service()
        _Keyword_Spotting_Service.model = tf.keras.models.load_model(SAVED_MODEL_PATH)
    return _Keyword_Spotting_Service._instance




if __name__ == "__main__":

    # create 2 instances of the keyword spotting service
    kss = Keyword_Spotting_Service()
    kss1 = Keyword_Spotting_Service()

    # check that different instances of the keyword spotting service point back to the same object (singleton)
    assert kss is kss1

    # make a prediction
    keyword = kss.predict("/content/gdrive/My Drive/tfg_audio/test/down.wav")
    print(keyword)
# Out:
# down

# %%
import random
import os
from flask import Flask, request, jsonify
#from keyword_spotting_service import Keyword_Spotting_Service


# instantiate flask app
app = Flask(__name__)


@app.route("/predict", methods=["POST"])
def predict():
	"""Endpoint to predict keyword
    :return (json): This endpoint returns a json file with the following format:
        {
            "keyword": "down"
        }
	"""

	# get file from POST request and save it
	audio_file = request.files["file"]
	file_name = str(random.randint(0, 100000))
	audio_file.save(file_name)

	# instantiate keyword spotting service singleton and get prediction
	kss = Keyword_Spotting_Service()
	predicted_keyword = kss.predict(file_name)

	# we don't need the audio file any more - let's delete it!
	os.remove(file_name)

	# send back result as a json file
	result = {"keyword": predicted_keyword}
	return jsonify(result)


if __name__ == "__main__":
    app.run(debug=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
import requests

# server url
URL = "http://127.0.0.1:5000/predict"


# audio file we'd like to send for predicting keyword
FILE_PATH = "/content/gdrive/My Drive/tfg_audio/test/down.wav"


if __name__ == "__main__":

    # open files
    file = open(FILE_PATH, "rb")

    # package stuff to send and perform POST request
    values = {"file": (FILE_PATH, file, "audio/wav")}
    response = requests.post(URL, files=values)
    data = response.json()

    print("Predicted keyword: {}".format(data["keyword"]))
